# %% [markdown]
# # Assignment: Data Wrangling

# %% [markdown]
# **Q1.** Open the "tidy_data.pdf" document in the repo, which is a paper called Tidy Data by Hadley Wickham.
#
#   1. Read the abstract. What is this paper about?
#   2. Read the introduction. What is the "tidy data standard" intended to accomplish?
#   3. Read the intro to section 2. What does this sentence mean: "Like families, tidy datasets are all alike but every messy dataset is messy in its own way." What does this sentence mean: "For a given dataset, it’s usually easy to figure out what are observations and what are variables, but it is surprisingly difficult to precisely define variables and observations in general."
#   4. Read Section 2.2. How does Wickham define values, variables, and observations?
#   5. How is "Tidy Data" defined in section 2.3?
#   6. Read the intro to Section 3 and Section 3.1. What are the 5 most common problems with messy datasets? Why are the data in Table 4 messy? What is "melting" a dataset?
#   7. Why, specifically, is table 11 messy but table 12 tidy and "molten"?
#   8. Read Section 6. What is the "chicken-and-egg" problem with focusing on tidy data? What does Wickham hope happens in the future with further work on the subject of data wrangling?

# %% [markdown]
# 1. This paper is about how tidy data can streamline the data cleaning process. It is mentioned that data cleaning, while used by every data scientist, does not have an efficient process. It describes a case study that will show how to "tidy" data properly
#
# 2. By standardizing data cleaning into the "tiny data" standard, there will be consistency and efficiency across the board of data cleaning. If all data is cleaned to a standard, then it can be more easily intrepreted since the objective is clear.
#
# 3. The first sentence means that tidy data is all organized the same and have similar properties. Messy data, on the other hand, is disorganized, not structured, and can nuances that are based on the people who created the data set. The second sentence nods to the fact that when looking at a data set, it is relitively easy based on the layout and titles to find which are observations (rows) and which are variables (columns). Even though orginazation is clear, it can be hard to give meaning to the observations and variables. This confusion cna lead to poor data cleaning.
#
# 4. A dataset is a collection of values which can be strings or numerical. Each value belongs to a variable and an observation. A variable is a collection of values that all measure the same attribute like height or temperature. An observation contians all values measured in the same unit like a day or person.
#
# 5. Tidy data is defined when each variable is a column, each observation is row, and each type of observational unit is a table.
#
# 6. The 5 most common problems with messy data sets are column headers are values and not variable names, multiple variables are stored in one column, variables are stored in both rows and columns, multiple types of observational units are stored in the same table, and single observational unit is stored in multiple tables. The data in table 4 are messy because the columns are values of "hidden" variables of income. To fix this, there should be a new variable called "income." Melting a dataset is the process of converting column-value variables into rows.
#
# 7. Table 11 has the value of days along the top. In tbale 12, those values are melted into the single variable of date. The table is still messy because the element variable has variable names tmax and tmin. Table 12b is tidy and molten becuase all the entries are attributes and not variable names.
#
# 8. It is a problem about local maxima when changing data structures and tools. If tidy data only works by using certain tools, then it is not functional. Wickman hopes that tidy data will transform and streamline the data cleaning world and create more tools and ideas.

# %% [markdown]
# **Q2.** This question provides some practice cleaning variables which have common problems.
# 1. Numeric variable: For `./data/airbnb_hw.csv`, clean the `Price` variable as well as you can, and explain the choices you make. How many missing values do you end up with? (Hint: What happens to the formatting when a price goes over 999 dollars, say from 675 to 1,112?)
# 2. Categorical variable: For the `./data/sharks.csv` data covered in the lecture, clean the "Type" variable as well as you can, and explain the choices you make.
# 3. Dummy variable: For the pretrial data covered in the lecture, clean the `WhetherDefendantWasReleasedPretrial` variable as well as you can, and, in particular, replace missing values with `np.nan`.
# 4. Missing values, not at random: For the pretrial data covered in the lecture, clean the `ImposedSentenceAllChargeInContactEvent` variable as well as you can, and explain the choices you make. (Hint: Look at the `SentenceTypeAllChargesAtConvictionInContactEvent` variable.)

# %%
! git clone https://github.com/DS3001/wrangling
# Out:
# Cloning into 'wrangling'...
# remote: Enumerating objects: 83, done.
# remote: Counting objects: 100% (40/40), done.
# remote: Compressing objects: 100% (29/29), done.
# remote: Total 83 (delta 31), reused 11 (delta 11), pack-reused 43
# Receiving objects: 100% (83/83), 10.85 MiB | 24.10 MiB/s, done.
# Resolving deltas: 100% (36/36), done.

# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
df = pd.read_csv('/content/wrangling/assignment/data/airbnb_hw.csv', low_memory=False)

# %%
print(df.shape, '\n')
df.head()
# Out:
# (30478, 13)
#     Host Id Host Since                                Name Neighbourhood   \
# 0   5162530        NaN     1 Bedroom in Prime Williamsburg       Brooklyn
# 1  33134899        NaN     Sunny, Private room in Bushwick       Brooklyn
# 2  39608626        NaN                Sunny Room in Harlem      Manhattan
# 3       500  6/26/2008  Gorgeous 1 BR with Private Balcony      Manhattan
# 4       500  6/26/2008            Trendy Times Square Loft      Manhattan
#
#   Property Type  Review Scores Rating (bin)        Room Type  Zipcode  Beds  \
# 0     Apartment                         NaN  Entire home/apt  11249.0   1.0
# 1     Apartment                         NaN     Private room  11206.0   1.0
# 2     Apartment                         NaN     Private room  10032.0   1.0
# 3     Apartment                         NaN  Entire home/apt  10024.0   3.0
# 4     Apartment                        95.0     Private room  10036.0   3.0
#
# ...

# %%
price = df['Price']
price.unique() #need to clean out the commas
# Out:
# array(['145', '37', '28', '199', '549', '149', '250', '90', '270', '290',
#        '170', '59', '49', '68', '285', '75', '100', '150', '700', '125',
#        '175', '40', '89', '95', '99', '499', '120', '79', '110', '180',
#        '143', '230', '350', '135', '85', '60', '70', '55', '44', '200',
#        '165', '115', '74', '84', '129', '50', '185', '80', '190', '140',
#        '45', '65', '225', '600', '109', '1,990', '73', '240', '72', '105',
#        '155', '160', '42', '132', '117', '295', '280', '159', '107', '69',
#        '239', '220', '399', '130', '375', '585', '275', '139', '260',
#        '35', '133', '300', '289', '179', '98', '195', '29', '27', '39',
#        '249', '192', '142', '169', '1,000', '131', '138', '113', '122',
#        '329', '101', '475', '238', '272', '308', '126', '235', '315',
#        '248', '128', '56', '207', '450', '215', '210', '385', '445',
#        '136', '247', '118', '77', '76', '92', '198', '205', '299', '222',
# ...

# %%
price = price.str.replace(',', '')
price = pd.to_numeric(price,errors='coerce')
print(price.unique(), '\n')
print('Total missing price values: ', sum(price.isnull()))
# Out:
# [  145    37    28   199   549   149   250    90   270   290   170    59
#     49    68   285    75   100   150   700   125   175    40    89    95
#     99   499   120    79   110   180   143   230   350   135    85    60
#     70    55    44   200   165   115    74    84   129    50   185    80
#    190   140    45    65   225   600   109  1990    73   240    72   105
#    155   160    42   132   117   295   280   159   107    69   239   220
#    399   130   375   585   275   139   260    35   133   300   289   179
#     98   195    29    27    39   249   192   142   169  1000   131   138
#    113   122   329   101   475   238   272   308   126   235   315   248
#    128    56   207   450   215   210   385   445   136   247   118    77
#     76    92   198   205   299   222   245   104   153   349   114   320
#    292   226   420   500   325   307    78   265   108   123   189    32
#     58    86   219   800   335    63   229   425    67    87  1200   158
# ...

# %%
sharks = pd.read_csv('/content/wrangling/data/sharks.csv', low_memory=False)
sharks.head()
# Out:
#    index   Case Number                  Date    Year        Type      Country  \
# 0      0    2020.02.05           05-Feb-2020  2020.0  Unprovoked          USA
# 1      1  2020.01.30.R  Reported 30-Jan-2020  2020.0    Provoked      BAHAMAS
# 2      2    2020.01.17           17-Jan-2020  2020.0  Unprovoked    AUSTRALIA
# 3      3    2020.01.16           16-Jan-2020  2020.0  Unprovoked  NEW ZEALAND
# 4      4    2020.01.13           13-Jan-2020  2020.0  Unprovoked          USA
#
#               Area               Location                  Activity  \
# 0             Maui                    NaN  Stand-Up Paddle boarding
# 1           Exumas                    NaN                  Floating
# 2  New South Wales          Windang Beach                   Surfing
# 3        Southland            Oreti Beach                   Surfing
# 4   North Carolina  Rodanthe, Dare County                   Surfing
#
#               Name  ... Unnamed: 246 Unnamed: 247 Unnamed: 248 Unnamed: 249  \
# ...

# %%
type = sharks['Type']
type.value_counts()
#change unknown variables to NaN instead of values
type = type.replace(['Invalid', 'Questionable', 'Unconfirmed', 'Unverified', 'Under investigation' ], np.nan)
type.value_counts()

#group all boating incidents together
type = type.replace(['Sea Disaster', 'Watercraft', 'Boat', 'Boatomg', 'Boating'], 'Watercraft')
type.value_counts()

df['Type'] = type
df['Type'].value_counts() #this puts the revised type variable back into the dataset
# Out:
# Unprovoked    4716
# Provoked       593
# Watercraft     583
# Name: Type, dtype: int64

# %%
#Dummy variable: For the pretrial data covered in the lecture, clean the WhetherDefendantWasReleasedPretrial variable as well as you can, and, in particular, replace missing values with np.nan.

url = 'http://www.vcsc.virginia.gov/pretrialdataproject/October%202017%20Cohort_Virginia%20Pretrial%20Data%20Project_Deidentified%20FINAL%20Update_10272021.csv'
trial = pd.read_csv(url,low_memory=False) # Pandas downloads and loads the .csv file for you

# %%
release = trial['WhetherDefendantWasReleasedPretrial']
print(release.value_counts())
#the 9 is unclear in the cookbook
release = release.replace(9,np.nan) #repalce 9 with nan
print(release.value_counts())

#check that there are the correct number of missing values, 31
print('Missing values: ',sum(release.isnull()))

 #put the revised release variable back into dataset
trial['WhetherDefendantWasReleasedPretrial'] = release
# Out:
# 1    19154
# 0     3801
# 9       31
# Name: WhetherDefendantWasReleasedPretrial, dtype: int64
# 1.0    19154
# 0.0     3801
# Name: WhetherDefendantWasReleasedPretrial, dtype: int64
# Missing values:  31

# %%
#Missing values, not at random: For the pretrial data covered in the lecture, clean the ImposedSentenceAllChargeInContactEvent variable as well as you can, and explain the choices you make. (Hint: Look at the SentenceTypeAllChargesAtConvictionInContactEvent variable.)

sentence = trial['ImposedSentenceAllChargeInContactEvent']
charge = trial['SentenceTypeAllChargesAtConvictionInContactEvent']
#print(charge.unique(), '\n')
#print(sentence.unique(), '\n') there are some missing values, some have '.'
sentence = pd.to_numeric(sentence,errors='coerce') #coerce to numeric value
sentence_NaN = sentence.isnull() #creates a dummy for missing values
print(np.sum(sentence_NaN), '\n') #see how many misisng values there are: 9053

print(pd.crosstab(sentence_NaN, charge), '\n') #missing cases are shown as a value of 4
sentence = sentence.mask(charge == 4, 0) #replaces missing values with a 0
sentence = sentence.mask(charge == 9, np.nan) #replaces the unknown 9 value as missing

sentence_NaN = sentence.isnull() #new dummy
print(pd.crosstab(sentence_NaN, charge), '\n') # now only 274 missing values

trial['ImposedSentenceAllChargeInContactEvent'] = sentence #replace the data with the clean version
# Out:
# 9053
#
# SentenceTypeAllChargesAtConvictionInContactEvent     0     1    2     4    9
# ImposedSentenceAllChargeInContactEvent
# False                                             8720  4299  914     0    0
# True                                                 0     0    0  8779  274
#
# SentenceTypeAllChargesAtConvictionInContactEvent     0     1    2     4    9
# ImposedSentenceAllChargeInContactEvent
# False                                             8720  4299  914  8779    0
# True                                                 0     0    0     0  274

# %% [markdown]
# **Q3.** Many important datasets contain a race variable, typically limited to a handful of values often including Black, White, Asian, Latino, and Indigenous. This question looks at data gathering efforts on this variable by the U.S. Federal government.
#
# 1. How did the most recent US Census gather data on race?
# 2. Why do we gather these data? What role do these kinds of data play in politics and society? Why does data quality matter?
# 3. Please provide a constructive criticism of how the Census was conducted: What was done well? What do you think was missing? How should future large scale surveys be adjusted to best reflect the diversity of the population? Could some of the Census' good practices be adopted more widely to gather richer and more useful data?
# 4. How did the Census gather data on sex and gender? Please provide a similar constructive criticism of their practices.
# 5. When it comes to cleaning data, what concerns do you have about protected characteristics like sex, gender, sexual identity, or race? What challenges can you imagine arising when there are missing values? What good or bad practices might people adopt, and why?
# 6. Suppose someone invented an algorithm to impute values for protected characteristics like race, gender, sex, or sexuality. What kinds of concerns would you have?

# %% [markdown]
# 1. The 2023 ACS census gathered data on race by frist giving a question on Hispanic origin, in which you can select the boxes that apply, as well as a drop down option to add more specific information. They also ask a seperate question in which you select the box that applies to you most (White, Africian American, American indian, etc...) and then are prompted to give more information about your origins.
#
# 2. There are many reasons to collect this data. Census data can allow for economic, social, or even political questions to form or lead to answers. It can be important to know where different demographic groups are and how people are spread. From the data, it can be determined what parts of the country are diverse, and how to foster this diversity. The quality of the data is vital. If economic, social, or poticial conclusions are drawn from data that is not high quality, there can be nagative implications. It is important that the data is high quality to alievate bias as well.
#
# 3. I think that the census did a good job having wide spread categories for questions, and specific questions within those categories. The posed questions, if answered accurately, can give very detailed data about the population. A wekaness of the census data collection could be the skewedness in questions aimed at those in the middle class or higher. I also think that there was a clear lack of inclusivenes in the sex/sexuality category. It does not give a drop down option or a fill i nthe blank for people to be specific and accurate in their answers.
# For the future, there should be an emphasis of questions having to do with personal identity being more openended and inclusive. The good practices of having a robust number of questions in a wide range of categories should be adopted to other studies.
#
# 4. The census gather info on sex by simply asking whether the person is male or female, and asks them to check one box only with no drop down choice. There is no additional question about gender. This is not inclusive of all people, and will result in inaccurate/non-detailed data. There should be more options, especially open-ended questions, to allow for everyone's identity to be included.
#
# 5. By not providing a place to input a unique drop down answer, or having no option for "prefer not to answer," the census data is not accurate. It is not a fair practice to require people to answer personal questions, or force them to confor mtheir identiy into a check box. A concern with missing values would be that a pre made model would try to "match" the individual with an identify based on their other answers. This is not a valid or accurate process, and includes bias into results.
#
# 6. I would have extreme concerns about bias. The algorithim has to be built based off of past data, and if that data is biased, then so will the algorithim. Another concern would be that the people who left answers blank, especially about questions regarding identity, do so with a reason. By filling in that value with a predicted identity, their choice of leaving their identity out is negated.
